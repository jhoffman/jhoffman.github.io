# %%
import json
import os

def update_json_files(root_dir, new_key, new_value):
    for dirpath, _, filenames in os.walk(root_dir):
        for filename in filenames:
            if filename.endswith(".json"):
                file_path = os.path.join(dirpath, filename)
                try:
                    with open(file_path, 'r', encoding='utf-8') as f:
                        data = json.load(f)
                    
                    # Add or update the key-value pair
                    data[new_key] = new_value

                    # Write back the updated JSON
                    with open(file_path, 'w', encoding='utf-8') as f:
                        json.dump(data, f, indent=2)
                    
                    print(f"Updated: {file_path}")
                except Exception as e:
                    print(f"Failed to update {file_path}: {e}")

# Example usage
#update_json_files("path/to/your/folder", "new_field", "your_value")

# %%
venue2month = {"bmvc": "11", "icml": "02", "cvpr": "06", "iclr": "05", 
               "icra": "05", "wacv": "01", "iccv": "10", 
               "neurips": "12", "nips": "12", "eccv": "10",
               "wafr": "10", "cvprw-ecv": "06",
              "eccv-workshop-ss": "10", "eccv-arow": "10", "eccvw-cviw": "10",
            "nipsw-multitask": "12", "nipsw-da": "12", "cvprw-ssad": "06",
               "cvpr-demo": "06", "iclrw": "05", "corl": "09", 
               "eccvw-webscale": "10", "neurips-vtta-workshop": "12",
               "cvpr-l3d-workshop": "06", "eccv-cadl-workshop": "10",
               "iros": "10", "icip": "09", "cikm": "10", "mlsysw-onedevice": "05"
              }

# %%
for dirpath, _, filenames in os.walk("."):
    for filename in filenames:
        if filename.endswith(".json"):
            file_path = os.path.join(dirpath, filename)
            try: 
                with open(file_path, 'r', encoding='utf-8') as f:
                    data = json.load(f)
                
                # Add or update the key-value pair
                if data["month"]: 
                    #print("Already has month", file_path)
                    data["month"] = int(data["month"])
                else:
                    data["month"] = venue2month[data["venue"]]
                
                # Write back the updated JSON
                with open(file_path, 'w', encoding='utf-8') as f:
                    json.dump(data, f, indent=2)
                
            except Exception as e:
                #print(data["venue"])
                print(f"Failed to update {file_path}: {e}")
